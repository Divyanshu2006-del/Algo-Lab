# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu2006-del/Algo-Lab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
# Prob_2: Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
# similar to example-1, also plot the graph (eg. even_odd )

def check_even_odd(number):
    # This operation takes a fixed amount of time, regardless of the 'number' value
    return 'Even' if number % 2 == 0 else 'Odd'

n_values_prob2 = list(range(1, 101))
time_values_prob2 = []

for n in n_values_prob2:
    # Simulate the operation. The time taken is constant, e.g., 1 unit.
    check_even_odd(n)
    time_values_prob2.append(1)

plt.figure()
plt.plot(n_values_prob2, time_values_prob2)
plt.xlabel("Input size n (number to check)")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n)) # Create a list of size n
    count_greater_than_zero(data)
    time_values.append(n) # The time taken is proportional to n

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity (Counting > 0 elements)")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import math

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0 # To simulate operations
    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps # Target not found, return total steps

n_values = list(range(1, 1001)) # Input sizes from 1 to 1000
time_values = []

for n in n_values:
    if n == 0:
        time_values.append(0) # Handle n=0 case if it were in n_values
        continue
    # The actual number of steps for binary search is approximately log2(n)
    # We will simulate this by appending log2(n) to time_values
    time_values.append(math.log2(n) + 1) # Add 1 because log2(1) is 0 but it takes at least 1 step

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (log n)")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search)")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import math
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            merged.append(left[left_idx])
            left_idx += 1
        else:
            merged.append(right[right_idx])
            right_idx += 1

    merged.extend(left[left_idx:])
    merged.extend(right[right_idx:])
    return merged

n_values = list(range(1, 201)) # Input sizes from 1 to 200
time_values = []

for n in n_values:
    if n == 0:
        time_values.append(0)
        continue
    # Simulate n log n complexity
    # Using base 2 logarithm for consistency with typical algorithm analysis
    time_values.append(n * math.log2(n))

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort)")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in polynomial time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

n_values = list(range(1, 101)) # Input sizes from 1 to 100
time_values = []

for n in n_values:
    # Simulate n^2 complexity
    time_values.append(n**2)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n^2)")
plt.title("O(n^2) Polynomial Time Complexity (e.g., Bubble Sort)")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in exponential time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt

def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

n_values = list(range(1, 20))  # Exponential growth is very fast, so keep n small
time_values = []

for n in n_values:
    # Simulate c^n complexity. For recursive fibonacci, it's roughly (1.618)^n
    # We'll use a simpler 2^n to illustrate the exponential growth for the plot
    time_values.append(2**n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (c^n)")
plt.title("O(c^n) Exponential Time Complexity (e.g., Recursive Fibonacci)")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np
import math

n_values = np.arange(1, 50) # Input sizes for the plot

# Calculate time values for different complexities
time_O1 = np.ones_like(n_values) # Constant
time_Ologn = np.log2(n_values) # Logarithmic
time_On = n_values # Linear
time_Onlogn = n_values * np.log2(n_values) # Log-linear
time_On2 = n_values**2 # Polynomial (n^2)
time_Oc_n = 2**n_values # Exponential (c^n, here c=2)

# Create the plot
plt.figure(figsize=(12, 8))

plt.plot(n_values, time_O1, label='O(1) - Constant', linestyle='-')
plt.plot(n_values, time_Ologn, label='O(log n) - Logarithmic', linestyle='--')
plt.plot(n_values, time_On, label='O(n) - Linear', linestyle='-.')
plt.plot(n_values, time_Onlogn, label='O(n log n) - Log-Linear', linestyle=':')
plt.plot(n_values, time_On2, label='O(n^2) - Polynomial', linestyle='-')
# For exponential, we might need a smaller range or scale to avoid extreme values
# Let's plot it for a slightly smaller range to make other complexities visible
plt.plot(n_values[:15], time_Oc_n[:15], label='O(2^n) - Exponential', linestyle='-', marker='o', markersize=4)

plt.xlabel("Input Size (n)")
plt.ylabel("Operations (Time)")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.ylim(0, 500) # Adjust y-limit to better visualize lower complexities
plt.xlim(0, 50)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)

import matplotlib.pyplot as plt
import numpy as np
import math
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Explanation of Quick Sort Time Complexity:
# Average case: O(n log n)
# The 'log n' component arises from the number of recursive calls, as the array is divided roughly in half each time.
# The 'n' component arises from the partitioning step, where each element is compared to the pivot.
# Worst case: O(n^2) (e.g., if the pivot selection consistently results in very unbalanced partitions)
# Best case: O(n log n)

# To simulate and plot O(n log n) (average case of Quick Sort):
# Note: Directly simulating the *exact* number of operations for quicksort for every 'n' can be complex.
# We will simulate the theoretical O(n log n) behavior, as this is the expected average complexity.

n_values = np.arange(1, 201) # Input sizes for plotting
time_values_nlogn = n_values * np.log2(n_values)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values_nlogn, label='O(n log n) - Quick Sort (Average)', color='blue')
plt.xlabel("Input Size (n)")
plt.ylabel("Operations (Time)")
plt.title("Simulated Average Time Complexity of Quick Sort (O(n log n))")
plt.legend()
plt.grid(True)
plt.show()
